# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import time

# %%
df=pd.read_csv("./data/survey_results_public.csv")
df1=df[['Respondent','DevType','LanguageWorkedWith','LanguageDesireNextYear','DatabaseWorkedWith','DatabaseDesireNextYear',
       'PlatformWorkedWith','PlatformDesireNextYear','FrameworkWorkedWith','FrameworkDesireNextYear']]
print(df1.columns)
# Out:
# Index(['Respondent', 'DevType', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'FrameworkWorkedWith',
#        'FrameworkDesireNextYear'],
#       dtype='object')

# %%
df=pd.read_csv("./data/survey_results_public.csv")
print(df.describe())
print(df.head())
print(df.columns)

n_row=df.shape[0]
print(df.isnull().sum()/n_row)
attr_to_drop=[]
attr_to_drop.append("SurveyTooLong")
attr_to_drop.append('SurveyEasy')
attr_to_drop.append("AdBlocker")
attr_to_drop.append("AdBlockerDisable")
attr_to_drop.append("AdBlockerReasons")
attr_to_drop.append("AdsAgreeDisagree1")
attr_to_drop.append("AdsAgreeDisagree2")
attr_to_drop.append("AdsAgreeDisagree3")
attr_to_drop.append("AdsActions")
attr_to_drop.append("AdsPriorities1")
attr_to_drop.append("AdsPriorities2")
attr_to_drop.append("AdsPriorities3")
attr_to_drop.append("AdsPriorities4")
attr_to_drop.append("AdsPriorities5")
attr_to_drop.append("AdsPriorities6")
attr_to_drop.append("AdsPriorities7")
attr_to_drop.append("AIDangerous")
attr_to_drop.append("AIInteresting")
attr_to_drop.append("AIResponsible")
attr_to_drop.append("AIFuture")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("EthicsReport")
attr_to_drop.append("EthicsResponsible")
attr_to_drop.append("EthicsImplications")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("StackOverflowRecommend")
attr_to_drop.append("StackOverflowVisit")
attr_to_drop.append("StackOverflowHasAccount")
attr_to_drop.append("StackOverflowParticipate")
attr_to_drop.append("StackOverflowJobs")
attr_to_drop.append("StackOverflowDevStory")
attr_to_drop.append("StackOverflowJobsRecommend")
attr_to_drop.append("StackOverflowConsiderMember")
attr_to_drop.append("HypotheticalTools1")
attr_to_drop.append("HypotheticalTools2")
attr_to_drop.append("HypotheticalTools3")
attr_to_drop.append("HypotheticalTools4")
attr_to_drop.append("HypotheticalTools5")
attr_to_drop.append("JobContactPriorities1")
attr_to_drop.append("JobContactPriorities2")
attr_to_drop.append("JobContactPriorities3")
attr_to_drop.append("JobContactPriorities4")
attr_to_drop.append("JobContactPriorities5")
attr_to_drop.append("TimeAfterBootcamp")
df=df.drop(df.columns[[126,3,8,15,50,51,53,62,63,64,123,125,43,44,45,46,47,48,49]],axis=1)
print(df.columns)
df=df[df.columns.difference(attr_to_drop)]
print(df.head())
attr_to_drop=["HackathonReasons","ErgonomicDevices"]
df=df[df.columns.difference(attr_to_drop)]


print(sum(df.isnull().sum())/float(np.prod(df.shape)))
col_null=df.isnull().sum()/n_row
print(col_null.sort_values(ascending=False))
# Out:
# C:\Users\S RITIKA\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# std        2.520499      2.502069      2.923998      2.507411      2.407457
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      2.000000      3.000000      2.000000      6.000000
# 50%        3.000000      4.000000      6.000000      4.000000      8.000000
# 75%        6.000000      6.000000      8.000000      6.000000     10.000000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...  JobEmailPriorities6  JobEmailPriorities7  ConvertedSalary  \
# count  ...          46213.00000         46213.000000     4.770200e+04
# mean   ...              4.97425             4.836388     9.578086e+04
# std    ...              1.86063             1.659844     2.023482e+05
# min    ...              1.00000             1.000000     0.000000e+00
# 25%    ...              4.00000             4.000000     2.384400e+04
# 50%    ...              5.00000             5.000000     5.507500e+04
# 75%    ...              7.00000             6.000000     9.300000e+04
# max    ...              7.00000             7.000000     2.000000e+06
#
#        AdsPriorities1  AdsPriorities2  AdsPriorities3  AdsPriorities4  \
# count    60479.000000    60479.000000    60479.000000    60479.000000
# mean         2.726880        3.805784        3.340945        3.782470
# std          1.881078        1.821323        1.673485        1.844864
# min          1.000000        1.000000        1.000000        1.000000
# 25%          1.000000        2.000000        2.000000        2.000000
# 50%          2.000000        4.000000        3.000000        4.000000
# 75%          4.000000        5.000000        5.000000        5.000000
# max          7.000000        7.000000        7.000000        7.000000
#
#        AdsPriorities5  AdsPriorities6  AdsPriorities7
# count    60479.000000    60479.000000    60479.000000
# mean         4.383604        5.138809        4.821459
# std          1.931746        1.853249        1.874895
# min          1.000000        1.000000        1.000000
# 25%          3.000000        4.000000        3.000000
# 50%          5.000000        6.000000        5.000000
# 75%          6.000000        7.000000        7.000000
# max          7.000000        7.000000        7.000000
#
# [8 rows x 42 columns]
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# 1  Database administrator;DevOps specialist;Full-...  ...
# 2           Engineering manager;Full-stack developer  ...
# 3                               Full-stack developer  ...
# 4  Data or business analyst;Desktop or enterprise...  ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)
# Respondent       0.000000
# Hobby            0.000000
# OpenSource       0.000000
# Country          0.004168
# Student          0.039998
#                    ...
# Age              0.346781
# Dependents       0.366790
# MilitaryUS       0.840362
# SurveyTooLong    0.332952
# SurveyEasy       0.333579
# Length: 129, dtype: float64
# Index(['Respondent', 'Hobby', 'OpenSource', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'DevType', 'YearsCoding',
#        'YearsCodingProf',
#        ...
#        'HoursOutside', 'SkipMeals', 'ErgonomicDevices', 'Exercise', 'Gender',
#        'SexualOrientation', 'EducationParents', 'Age', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=110)
#                  Age  AssessBenefits1  AssessBenefits10  AssessBenefits11  \
# 0  25 - 34 years old              NaN               NaN               NaN
# 1  35 - 44 years old              1.0               2.0               8.0
# 2                NaN              NaN               NaN               NaN
# 3  35 - 44 years old              NaN               NaN               NaN
# 4  18 - 24 years old              1.0               9.0               6.0
#
#    AssessBenefits2  AssessBenefits3  AssessBenefits4  AssessBenefits5  \
# 0              NaN              NaN              NaN              NaN
# 1              5.0              3.0              7.0             10.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4             10.0              2.0              4.0              8.0
#
#    AssessBenefits6  AssessBenefits7  ...  \
# 0              NaN              NaN  ...
# 1              4.0             11.0  ...
# 2              NaN              NaN  ...
# 3              NaN              NaN  ...
# 4              3.0             11.0  ...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1  The official documentation and/or standards fo...
# 2                                                NaN
# 3  The official documentation and/or standards fo...
# 4  The official documentation and/or standards fo...
#
#           SexualOrientation             SkipMeals         Student  \
# 0  Straight or heterosexual                 Never              No
# 1  Straight or heterosexual                 Never              No
# 2                       NaN                   NaN              No
# 3  Straight or heterosexual  3 - 4 times per week              No
# 4  Straight or heterosexual                 Never  Yes, part-time
#
#    TimeFullyProductive                                     UndergradMajor  \
# 0  One to three months                          Mathematics or statistics
# 1  One to three months  A natural science (ex. biology, chemistry, phy...
# 2                  NaN  Computer science, computer engineering, or sof...
# 3  Three to six months  Computer science, computer engineering, or sof...
# 4  Three to six months  Computer science, computer engineering, or sof...
#
#       VersionControl                WakeTime       YearsCoding  \
# 0                Git  Between 5:00 - 6:00 AM         3-5 years
# 1     Git;Subversion  Between 6:01 - 7:00 AM  30 or more years
# 2                NaN                     NaN       24-26 years
# 3                Git  Between 6:01 - 7:00 AM       18-20 years
# 4  Zip file back-ups          Before 5:00 AM         6-8 years
#
#    YearsCodingProf
# 0        3-5 years
# 1      18-20 years
# 2        6-8 years
# 3      12-14 years
# 4        0-2 years
#
# [5 rows x 68 columns]
# 0.29139955521018696
# ConvertedSalary            0.517455
# Salary                     0.488362
# FrameworkWorkedWith        0.477821
# TimeFullyProductive        0.475272
# FrameworkDesireNextYear    0.441424
#                              ...
# Student                    0.039998
# Employment                 0.035749
# Hobby                      0.000000
# OpenSource                 0.000000
# Respondent                 0.000000
# Length: 66, dtype: float64

# %%
attr_to_drop=['Hobby','NumberMonitors','Salary','CheckInCode','WakeTime','TimeFullyProductive','SkipMeals','SexualOrientation','HoursOutside','Exercise','EthicalImplications','EducationParents']

df=df[df.columns.difference(attr_to_drop)]

# %%
import numpy as np
df1 = df.replace(np.nan, '', regex=True)

# %%
Frameworknextyear=list()
for value in df1["FrameworkDesireNextYear"]:
        new=value.split(';')
        for i in new:
            Frameworknextyear.append(i)
sFNY=set(Frameworknextyear)
FrameworkWorkedWith=list()
for value in df1["FrameworkWorkedWith"]:
        new=value.split(';')
        for i in new:
            FrameworkWorkedWith.append(i)
sFW=set(FrameworkWorkedWith)
PlatformDesireNextYear=list()
for value in df1["PlatformDesireNextYear"]:
        new=value.split(';')
        for i in new:
            PlatformDesireNextYear.append(i)
sPDNY=set(PlatformDesireNextYear)
PlatformWorkedWith=list()
for value in df1["PlatformWorkedWith"]:
        new=value.split(';')
        for i in new:
            PlatformWorkedWith.append(i)
sPWW=set(PlatformWorkedWith)
LanguageDesireNextYear=list()
for value in df1["LanguageDesireNextYear"]:
        new=value.split(';')
        for i in new:
            LanguageDesireNextYear.append(i)
sLDNY=set(LanguageDesireNextYear)
LanguageWorkedWith=list()
for value in df1["LanguageWorkedWith"]:
    new=value.split(';')
    for i in new:
        LanguageWorkedWith.append(i)
sLWW=set(LanguageWorkedWith)
         
CommunicationTools=list()
for value in df1["CommunicationTools"]:
        new=value.split(';')
        for i in new:
            CommunicationTools.append(i)
sCT=set(CommunicationTools)

DatabaseWorkedWith=list()
for value in df1["DatabaseWorkedWith"]:
        new=value.split(';')
        for i in new:
            DatabaseWorkedWith.append(i)
sDWW=set(DatabaseWorkedWith)

DatabaseDesireNextYear=list()
for value in df1["DatabaseDesireNextYear"]:
        new=value.split(';')
        for i in new:
            DatabaseDesireNextYear.append(i)
sDNY=set(DatabaseDesireNextYear)

# %%
DevType=list()
for value in df1["DevType"]:
        new=value.split(';')
        for i in new:
            DevType.append(i)
sDT=set(DevType)
sFNY.remove("")
sFW.remove("")
sPDNY.remove("")
sPWW.remove("")
sLDNY.remove("")
sLWW.remove("")
sCT.remove("")
sDWW.remove("")
sDNY.remove("")
sDT.remove("")
print(sFNY)
print(sFW)
print(sPDNY)
print(sPWW)
print(sLDNY)
print(sLWW)
print(sCT)
print(sDWW)
print(sDNY)
print(sDT)
combined=sFNY.union(sFW,sFNY,sPDNY,sPWW,sLDNY,sLWW,sCT,sDWW,sDNY,sDT)
print(type(combined))
all_framework=list(combined)
print(all_framework)
all_fw=pd.DataFrame(all_framework)
# Out:
# {'Xamarin', 'Spark', 'Django', 'Cordova', '.NET Core', 'Node.js', 'Torch/PyTorch', 'Angular', 'React', 'Hadoop', 'Spring', 'TensorFlow'}
# {'Xamarin', 'Spark', 'Django', 'Cordova', 'Node.js', '.NET Core', 'Torch/PyTorch', 'Angular', 'React', 'Hadoop', 'Spring', 'TensorFlow'}
# {'Google Home', 'Azure', 'ESP8266', 'WordPress', 'Android', 'Heroku', 'Windows Desktop or Server', 'Amazon Echo', 'Firebase', 'Mainframe', 'Google Cloud Platform/App Engine', 'AWS', 'Drupal', 'Serverless', 'Raspberry Pi', 'SharePoint', 'Salesforce', 'Gaming console', 'iOS', 'Apple Watch or Apple TV', 'Windows Phone', 'Linux', 'Arduino', 'Predix', 'IBM Cloud or Watson', 'Mac OS'}
# {'Google Home', 'Azure', 'ESP8266', 'WordPress', 'Android', 'Heroku', 'Windows Desktop or Server', 'Amazon Echo', 'Firebase', 'Mainframe', 'Google Cloud Platform/App Engine', 'AWS', 'Drupal', 'Raspberry Pi', 'Serverless', 'SharePoint', 'Salesforce', 'Gaming console', 'iOS', 'Apple Watch or Apple TV', 'Windows Phone', 'Linux', 'Arduino', 'Predix', 'IBM Cloud or Watson', 'Mac OS'}
# {'Matlab', 'JavaScript', 'Perl', 'F#', 'CSS', 'TypeScript', 'C', 'R', 'Clojure', 'Cobol', 'Ocaml', 'Bash/Shell', 'SQL', 'C++', 'Visual Basic 6', 'Python', 'Erlang', 'Kotlin', 'Java', 'CoffeeScript', 'Rust', 'C#', 'Delphi/Object Pascal', 'Objective-C', 'VB.NET', 'Groovy', 'Lua', 'Ruby', 'HTML', 'Swift', 'Assembly', 'Scala', 'Julia', 'Go', 'Haskell', 'VBA', 'Hack', 'PHP'}
# {'Matlab', 'JavaScript', 'Perl', 'F#', 'CSS', 'TypeScript', 'C', 'R', 'Cobol', 'Clojure', 'Ocaml', 'Bash/Shell', 'SQL', 'C++', 'Visual Basic 6', 'Python', 'Erlang', 'Kotlin', 'Java', 'CoffeeScript', 'Rust', 'C#', 'Delphi/Object Pascal', 'Objective-C', 'VB.NET', 'Groovy', 'Lua', 'Ruby', 'HTML', 'Swift', 'Assembly', 'Scala', 'Julia', 'Go', 'Haskell', 'VBA', 'Hack', 'PHP'}
# {'Other wiki tool (Github, Google Sites, proprietary software, etc.)', 'Facebook', 'Stack Overflow Enterprise', 'Confluence', 'HipChat', 'Jira', 'Office / productivity suite (Microsoft Office, Google Suite, etc.)', 'Slack', 'Trello', 'Google Hangouts/Chat', 'Other chat system (IRC, proprietary software, etc.)'}
# {'Amazon RDS/Aurora', 'Oracle', 'MariaDB', 'IBM Db2', 'Amazon Redshift', 'MySQL', 'Memcached', 'Neo4j', 'Elasticsearch', 'PostgreSQL', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'MongoDB', 'Amazon DynamoDB', 'Apache Hive', 'Redis', 'Cassandra', 'SQLite', 'Apache HBase', 'SQL Server', 'Google BigQuery', 'Google Cloud Storage'}
# {'Amazon RDS/Aurora', 'Oracle', 'MariaDB', 'IBM Db2', 'Amazon Redshift', 'MySQL', 'Memcached', 'Neo4j', 'Elasticsearch', 'PostgreSQL', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'MongoDB', 'Amazon DynamoDB', 'Apache Hive', 'Redis', 'Cassandra', 'SQLite', 'Apache HBase', 'SQL Server', 'Google BigQuery', 'Google Cloud Storage'}
# {'C-suite executive (CEO, CTO, etc.)', 'DevOps specialist', 'Product manager', 'Database administrator', 'QA or test developer', 'Embedded applications or devices developer', 'Game or graphics developer', 'Full-stack developer', 'Engineering manager', 'Data or business analyst', 'Marketing or sales professional', 'Educator or academic researcher', 'Back-end developer', 'Desktop or enterprise applications developer', 'Designer', 'Student', 'Front-end developer', 'Mobile developer', 'Data scientist or machine learning specialist', 'System administrator'}
# <class 'set'>
# ['Google Home', 'Xamarin', 'Matlab', 'TensorFlow', 'JavaScript', '.NET Core', 'ESP8266', 'Perl', 'CSS', 'TypeScript', 'Product manager', 'Amazon RDS/Aurora', 'Database administrator', 'React', 'Android', 'Ocaml', 'Google Hangouts/Chat', 'Bash/Shell', 'SQL', 'Game or graphics developer', 'Full-stack developer', 'Erlang', 'Engineering manager', 'Stack Overflow Enterprise', 'Amazon Redshift', 'Amazon Echo', 'Java', 'Trello', 'Marketing or sales professional', 'Educator or academic researcher', 'MySQL', 'Back-end developer', 'Drupal', 'Memcached', 'Desktop or enterprise applications developer', 'Designer', 'Salesforce', 'Neo4j', 'Rust', 'PostgreSQL', 'Objective-C', 'Lua', 'iOS', 'Apple Watch or Apple TV', 'Spring', 'Mobile developer', 'Assembly', 'Data scientist or machine learning specialist', 'Windows Phone', 'Spark', 'HipChat', 'Linux', 'Redis', 'Cassandra', 'Haskell', 'SQLite', 'Arduino', 'Apache HBase', 'Hadoop', 'VBA', 'SQL Server', 'IBM Cloud or Watson', 'Google BigQuery', 'Google Cloud Storage', 'Facebook', 'C-suite executive (CEO, CTO, etc.)', 'Azure', 'Slack', 'F#', 'Clojure', 'WordPress', 'C', 'R', 'Cobol', 'Oracle', 'DevOps specialist', 'QA or test developer', 'Embedded applications or devices developer', 'Other chat system (IRC, proprietary software, etc.)', 'Visual Basic 6', 'C++', 'MariaDB', 'Heroku', 'Python', 'Windows Desktop or Server', 'Django', 'IBM Db2', 'Jira', 'Node.js', 'Kotlin', 'Office / productivity suite (Microsoft Office, Google Suite, etc.)', 'Firebase', 'Data or business analyst', 'Mainframe', 'Google Cloud Platform/App Engine', 'CoffeeScript', 'AWS', 'Serverless', 'Raspberry Pi', 'SharePoint', 'Other wiki tool (Github, Google Sites, proprietary software, etc.)', 'C#', 'Confluence', 'Cordova', 'Elasticsearch', 'Gaming console', 'Delphi/Object Pascal', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'VB.NET', 'Groovy', 'MongoDB', 'Student', 'Front-end developer', 'Ruby', 'HTML', 'Swift', 'Scala', 'Torch/PyTorch', 'Amazon DynamoDB', 'Apache Hive', 'Julia', 'Go', 'System administrator', 'Angular', 'Predix', 'Hack', 'PHP', 'Mac OS']

# %%
from sklearn.preprocessing import LabelEncoder
print(set(df1['JobSatisfaction']))
number=LabelEncoder()
df1['CareerSatisfaction']=number.fit_transform(df1['CareerSatisfaction'])
df1['Employment']=number.fit_transform(df1['Employment'])
df1['FormalEducation']=number.fit_transform(df1['FormalEducation'])
df1['Gender']=number.fit_transform(df1['Gender'])
df1['HopeFiveYears']=number.fit_transform(df1['HopeFiveYears'])
df1['HoursComputer']=number.fit_transform(df1['HoursComputer'])
df1['JobSatisfaction']=number.fit_transform(df1['JobSatisfaction'])
df1['OpenSource']=number.fit_transform(df1['OpenSource'])
df1['OperatingSystem']=number.fit_transform(df1['OperatingSystem'])
df1['Student']=number.fit_transform(df1['Student'])
df1['UndergradMajor']=number.fit_transform(df1['UndergradMajor'])
df1['YearsCoding']=number.fit_transform(df1['YearsCoding'])
df1['YearsCodingProf']=number.fit_transform(df1['YearsCodingProf'])
# Out:
# {'', 'Slightly dissatisfied', 'Moderately dissatisfied', 'Extremely dissatisfied', 'Slightly satisfied', 'Neither satisfied nor dissatisfied', 'Moderately satisfied', 'Extremely satisfied'}

# %%
FrameworkWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sFW:
    
    FrameworkWorkedWith[i]=""
PlatformWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sPWW:
    print(i)
    PlatformWorkedWith[i]=""
LanguageWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sLWW:
    LanguageWorkedWith[i]=""
DatabaseWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sDWW:
    DatabaseWorkedWith[i]=""
DevType = pd.DataFrame(df1['Respondent'])
for i in sDT:
    DevType[i]=""
CommunicationTools = pd.DataFrame(df1['Respondent'])
for i in sCT:
    CommunicationTools[i]=""

print(len(sFW))
print(len(sPWW))
# Out:
# Google Home
# Azure
# ESP8266
# WordPress
# Android
# Heroku
# Windows Desktop or Server
# Amazon Echo
# Firebase
# Mainframe
# Google Cloud Platform/App Engine
# AWS
# Drupal
# Raspberry Pi
# Serverless
# SharePoint
# Salesforce
# Gaming console
# iOS
# Apple Watch or Apple TV
# Windows Phone
# Linux
# Arduino
# Predix
# IBM Cloud or Watson
# Mac OS
# 12
# 26

# %%
time_start=time.time()
coldic=dict(zip(FrameworkWorkedWith.columns,range(0,len(sFW)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'FrameworkWorkedWith']).split(';')
    if(data[0]!=""):
       
        for value in data:
            FrameworkWorkedWith.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)

coldic1=dict(zip(PlatformWorkedWith.columns,range(0,len(sPWW)+1)))
print(coldic1)

for i in range(98855):
    data=(df1.loc[i,'PlatformWorkedWith']).split(';')
    if(data[0]!=""):
       
        for value in data:
            PlatformWorkedWith.iloc[i,coldic1[value]]=1
# Out:
# {'Respondent': 0, 'Xamarin': 1, 'Spark': 2, 'Django': 3, 'Cordova': 4, 'Node.js': 5, '.NET Core': 6, 'Torch/PyTorch': 7, 'Angular': 8, 'React': 9, 'Hadoop': 10, 'Spring': 11, 'TensorFlow': 12}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 264.31696939468384
# {'Respondent': 0, 'Google Home': 1, 'Azure': 2, 'ESP8266': 3, 'WordPress': 4, 'Android': 5, 'Heroku': 6, 'Windows Desktop or Server': 7, 'Amazon Echo': 8, 'Firebase': 9, 'Mainframe': 10, 'Google Cloud Platform/App Engine': 11, 'AWS': 12, 'Drupal': 13, 'Raspberry Pi': 14, 'Serverless': 15, 'SharePoint': 16, 'Salesforce': 17, 'Gaming console': 18, 'iOS': 19, 'Apple Watch or Apple TV': 20, 'Windows Phone': 21, 'Linux': 22, 'Arduino': 23, 'Predix': 24, 'IBM Cloud or Watson': 25, 'Mac OS': 26}

# %%
time_LWW=time.time()
coldic2=dict(zip(LanguageWorkedWith.columns,range(0,len(sLWW)+1)))
print(coldic2)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'LanguageWorkedWith']).split(';')
    if(data[0]!=""):
      
        for value in data:
            LanguageWorkedWith.iloc[i,coldic2[value]]=1
time_LWWe=time.time()
print("Language",time_LWWe-time_LWW)
print("done")

time_DWW=time.time()
coldic3=dict(zip(DatabaseWorkedWith.columns,range(0,len(sDWW)+1)))
print(coldic3)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'DatabaseWorkedWith']).split(';')
    if(data[0]!=""):
       
        for value in data:
            DatabaseWorkedWith.iloc[i,coldic3[value]]=1
time_DWWe=time.time()
print("Databases",time_DWWe-time_DWW)
# Out:
# {'Respondent': 0, 'Matlab': 1, 'JavaScript': 2, 'Perl': 3, 'F#': 4, 'CSS': 5, 'TypeScript': 6, 'C': 7, 'R': 8, 'Cobol': 9, 'Clojure': 10, 'Ocaml': 11, 'Bash/Shell': 12, 'SQL': 13, 'C++': 14, 'Visual Basic 6': 15, 'Python': 16, 'Erlang': 17, 'Kotlin': 18, 'Java': 19, 'CoffeeScript': 20, 'Rust': 21, 'C#': 22, 'Delphi/Object Pascal': 23, 'Objective-C': 24, 'VB.NET': 25, 'Groovy': 26, 'Lua': 27, 'Ruby': 28, 'HTML': 29, 'Swift': 30, 'Assembly': 31, 'Scala': 32, 'Julia': 33, 'Go': 34, 'Haskell': 35, 'VBA': 36, 'Hack': 37, 'PHP': 38}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# Language 968.1120352745056
# done
# {'Respondent': 0, 'Amazon RDS/Aurora': 1, 'Oracle': 2, 'MariaDB': 3, 'IBM Db2': 4, 'Amazon Redshift': 5, 'MySQL': 6, 'Memcached': 7, 'Neo4j': 8, 'Elasticsearch': 9, 'PostgreSQL': 10, 'Microsoft Azure (Tables, CosmosDB, SQL, etc)': 11, 'MongoDB': 12, 'Amazon DynamoDB': 13, 'Apache Hive': 14, 'Redis': 15, 'Cassandra': 16, 'SQLite': 17, 'Apache HBase': 18, 'SQL Server': 19, 'Google BigQuery': 20, 'Google Cloud Storage': 21}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# Databases 388.1489226818085

# %%
time_DT=time.time()
coldic4=dict(zip(DevType.columns,range(0,len(sDT)+1)))
print(coldic4)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'DevType']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            DevType.iloc[i,coldic4[value]]=1
time_DTe=time.time()
print("DevType",time_DTe-time_DT)
#CommmunicationTools
coldic5=dict(zip(CommunicationTools.columns,range(0,len(sCT)+1)))
print(coldic5)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'CommunicationTools']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            CommunicationTools.iloc[i,coldic5[value]]=1
# Out:
# {'Respondent': 0, 'C-suite executive (CEO, CTO, etc.)': 1, 'DevOps specialist': 2, 'Product manager': 3, 'Database administrator': 4, 'QA or test developer': 5, 'Embedded applications or devices developer': 6, 'Game or graphics developer': 7, 'Full-stack developer': 8, 'Engineering manager': 9, 'Data or business analyst': 10, 'Marketing or sales professional': 11, 'Educator or academic researcher': 12, 'Back-end developer': 13, 'Desktop or enterprise applications developer': 14, 'Designer': 15, 'Student': 16, 'Front-end developer': 17, 'Mobile developer': 18, 'Data scientist or machine learning specialist': 19, 'System administrator': 20}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# DevType 622.2687215805054
# {'Respondent': 0, 'Other wiki tool (Github, Google Sites, proprietary software, etc.)': 1, 'Facebook': 2, 'Stack Overflow Enterprise': 3, 'Confluence': 4, 'HipChat': 5, 'Jira': 6, 'Office / productivity suite (Microsoft Office, Google Suite, etc.)': 7, 'Slack': 8, 'Trello': 9, 'Google Hangouts/Chat': 10, 'Other chat system (IRC, proprietary software, etc.)': 11}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]

# %%
FrameworkWorkedWith.to_csv("./data/FrameworkWorkedWith.csv")
PlatformWorkedWith.to_csv("./data/PlatformWorkedWith.csv")

LanguageWorkedWith.to_csv("./data/LanguageWorkedWith.csv")
DatabaseWorkedWith.to_csv("./data/DatabaseWorkedWith.csv")
CommunicationTools.to_csv("./data/CommunicationTools.csv")
DevType.to_csv("./data/DevType.csv")

# %%
# Out:
# {'Respondent': 0, 'Google Home': 1, 'Azure': 2, 'ESP8266': 3, 'WordPress': 4, 'Android': 5, 'Heroku': 6, 'Windows Desktop or Server': 7, 'Amazon Echo': 8, 'Firebase': 9, 'Mainframe': 10, 'Google Cloud Platform/App Engine': 11, 'AWS': 12, 'Drupal': 13, 'Serverless': 14, 'Raspberry Pi': 15, 'SharePoint': 16, 'Salesforce': 17, 'Gaming console': 18, 'iOS': 19, 'Apple Watch or Apple TV': 20, 'Windows Phone': 21, 'Linux': 22, 'Arduino': 23, 'Predix': 24, 'IBM Cloud or Watson': 25, 'Mac OS': 26}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7  ... OperatingSystem  \
# 0                                  ...               2
# 1               4              11  ...               2
# 2                                  ...               0
# 3                                  ...               4
# 4               3              11  ...               4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8e6130e2cab9> in <module>
#      12        # print(data)
#      13         for value in data:
# ---> 14             PlatformDesireNextYear.iloc[i,coldic[value]]=1
#      15 time_end=time.time()
#      16 print(time_end-time_start)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1763                 # scalar value
#    1764                 for loc in ilocs:
# -> 1765                     isetter(loc, value)
#    1766
#    1767         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in isetter(loc, v)
#    1688                 else:
#    1689                     # set the item, possibly having a dtype change
# -> 1690                     ser = ser.copy()
#    1691                     ser._mgr = ser._mgr.setitem(indexer=pi, value=v)
#    1692                     ser._maybe_update_cacher(clear=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5661         dtype: object
#    5662         """
# -> 5663         data = self._mgr.copy(deep=deep)
#    5664         self._clear_item_cache()
#    5665         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     800             new_axes = list(self.axes)
#     801
# --> 802         res = self.apply("copy", deep=deep)
#     803         res.axes = new_axes
#     804         return res
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     677         values = self.values
#     678         if deep:
# --> 679             values = values.copy()
#     680         return self.make_block_same_class(values, ndim=self.ndim)
#     681
#
# KeyboardInterrupt:
